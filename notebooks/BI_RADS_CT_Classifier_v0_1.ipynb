# %%
#Download the required libraries
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import matplotlib.pyplot as plt
import torchvision
from torchvision import datasets, models
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import torch.onnx
import torchvision

# %matplotlib inline

plt.ion()   # interactive mode

# %% [markdown]
# **ЗАГРУЗКА ДАННЫХ**

# %%
#Получаю адрес папки /content (папка диска)
dir = os.path.abspath(os.curdir)
# указываем путь до датасета 
data_dir=os.path.join(dir, "/content/drive/My Drive/DATA")

# Масштабируем данные до 224*224 и нормализуем для train и test
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
}

#Создаю функцию для загрузки изображений из датасета и ресайза для модели Create function to get your(my) images dataset and resize it to size for model
def get_dataset(data_dir, data_transforms):

    # Создаю train и test датасеты
    image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                              data_transforms[x])
                      for x in ['train', 'test']}
    dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                                 shuffle=True, num_workers=4)
                  for x in ['train', 'test']}
    dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test']}
    #Получаем классы из имен папок train датасета
    classes = image_datasets['train'].classes

    return dataloaders["train"], dataloaders['test'], classes, dataset_sizes

# %%
# Загружаем данные train и test
trainloader, testloader, classes, dataset_sizes=get_dataset(data_dir,data_transforms)
print('Классов: ',  classes)
print('Набор данных содержит: ',  dataset_sizes ," снимков")
# Out:
# Классов:  ['0', '1']
# Набор данных содержит:  {'train': 1331, 'test': 378}  снимков

# %% [markdown]
# **ПРЕДПОДГОТОВКА ИЗОБРАЖЕНИЙ**

# %%
# Функция для создания нового изображения после трансформации 
def imshow_DenseNet(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # пауза для обновления графика

# %% [markdown]
# **СОЗДАНИЕ МОДЕЛИ**

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Каждая эпоха имеет свою фазу обучения и проверки
        for phase in ['train', 'test']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Перебираем данные
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Обнуляем градиент
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + оптимизатор только в тренировочной фазе
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # статистика
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'test' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
dataloaders = {'train': trainloader, 'test': testloader}
# model_ft = models.resnet18(pretrained=True) - было
model_ft = torch.hub.load('pytorch/vision:v0.6.0', 'densenet121', pretrained=True)
num_ftrs = model_ft.classifier.in_features
# Здесь размер каждого выходного образца устанавливается равным числу классов.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.classifier = nn.Sequential(nn.Linear(num_ftrs, 256), 
                                    nn.ReLU(), 
                                    nn.Dropout(0.4), 
                                    nn.Linear(256, len(classes))) 

device = 'cuda'
model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Оптимизируем все параметры
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Снижение LR каждые 7 эпох 
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# Downloading: "https://github.com/pytorch/vision/archive/v0.6.0.zip" to /root/.cache/torch/hub/v0.6.0.zip
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# HBox(children=(FloatProgress(value=0.0, max=32342954.0), HTML(value='')))

# %% [markdown]
# **ОБУЧЕНИЕ МОДЕЛИ**

# %%
#Train the model
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=5)
# Out:
# Epoch 0/4
# ----------
# train Loss: 0.2616 Acc: 0.9264
# test Loss: 0.2074 Acc: 0.9392
#
# Epoch 1/4
# ----------
# train Loss: 0.2450 Acc: 0.9294
# test Loss: 0.1883 Acc: 0.9392
#
# Epoch 2/4
# ----------
# train Loss: 0.2212 Acc: 0.9294
# test Loss: 0.2103 Acc: 0.9392
#
# Epoch 3/4
# ----------
# train Loss: 0.2213 Acc: 0.9294
# test Loss: 0.1791 Acc: 0.9392
#
# Epoch 4/4
# ----------
# train Loss: 0.2070 Acc: 0.9301
# test Loss: 0.1787 Acc: 0.9392
#
# Training complete in 38m 21s
# Best val Acc: 0.939153

# %% [markdown]
# **РЕЗУЛЬТАТЫ МОДЕЛИ**

# %%
# Визуализируем результаты
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.cuda(), labels.cuda()
        outputs = model_ft(images)
        _, predicted = torch.max(outputs.data, 1)
        
        for printdata in list(zip(predicted,labels,outputs)):
            printclass =[classes[int(printdata[0])],classes[int(printdata[1])]]
            print('Predict class - {0}, real class - {1}, probability ({2},{3}) - {4}'.format( printclass[0],printclass[1],
                                                                              classes[0], classes [1],printdata[2]))

        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        # imshow_DenseNet(torchvision.utils.make_grid(images))
        #print('GroundTruth: ', ' '.join('%5s' % classes[predicted[j]] for j in range(4)))
device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.0139,  0.6730], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.4010,  1.2338], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-0.8124,  0.7985], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.5910,  1.3692], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.5701,  1.2105], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3570,  0.9383], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-0.8269,  0.6011], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.8028,  1.2447], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-0.9214,  0.6364], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3108,  1.1637], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.1513,  0.9711], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.4498,  1.0053], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-2.4352,  1.9013], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-2.0736,  1.9139], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-0.8382,  0.8010], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.2605,  1.0757], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.6022,  1.0595], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.2371,  1.1609], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.7241,  1.3617], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3889,  0.9320], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.0058,  0.6858], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.2722,  1.0336], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.8440,  1.2138], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.1417,  0.9433], device='cuda:0')
# Predict class - 1, real class - 0, probability (0,1) - tensor([-0.7673,  0.5358], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.5983,  1.2373], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.6656,  1.4243], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.0005,  0.7727], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-0.9843,  0.8593], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.5050,  1.2218], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.1797,  1.0768], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3499,  0.8312], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-2.0707,  1.4828], device='cuda:0')
# Predict class - 1, real class - 0, probability (0,1) - tensor([-1.2261,  0.7643], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.2859,  0.9097], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.2023,  0.9877], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.4115,  0.7040], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.1383,  0.9345], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-2.1644,  1.7824], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3883,  1.1931], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.1495,  0.7830], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.4272,  1.2620], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.1861,  0.7302], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-0.8633,  0.7261], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-0.8051,  0.5407], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3732,  1.2608], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.5183,  1.1754], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3291,  0.8682], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3107,  0.9931], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3577,  1.1316], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3112,  1.0653], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-0.9324,  0.5633], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3739,  1.1466], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-0.5801,  0.5349], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-2.4889,  2.1589], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.0550,  0.8440], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3519,  1.0938], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.8173,  1.6627], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.5906,  1.2829], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3469,  0.9744], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.0663,  0.9935], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3238,  1.1282], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3687,  0.8968], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.9375,  1.5156], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.8680,  1.5700], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.5248,  1.1558], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.1782,  0.9737], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.6645,  1.2584], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.0348,  0.8001], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-0.9342,  0.8032], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.2063,  0.8469], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.3732,  1.2608], device='cuda:0')
# Predict class - 1, real class - 1, probability (0,1) - tensor([-1.1432,  0.9203], device='cuda:0')
# Accuracy of the network on the 378 test images: 93 %

# %% [markdown]
# **СОХРАНЯЕМ МОДЕЛЬ**

# %%
# Сохраним обученную модель
dir='/content/drive/My Drive/MODELS CT/'
PATH =os.path.join(dir, "model v0.1")
torch.save(model_ft, PATH)

# %% [markdown]
# **ИСПОЛЬЗУЕМ ОБУЧЕННУЮ МОДЕЛЬ ДЛЯ ПРЕДСКАЗАНИЙ НА РАБОЧИХ ДАННЫХ**

# %%
modelBR=torch.load('/content/drive/My Drive/MODELS CT/model v0.1(CT)')

# %%
dir='/content/drive/My Drive/MODELS CT/'
PATH = os.path.join(dir, "model.pt")
torch.save(modelBR.state_dict(), PATH)

# %% [markdown]
# Загружаем и преобразуем изображение в модель

# %%
path_file = '/content/drive/My Drive/MODELS CT/fulltestdata/'
transforms_file = transforms.Compose([transforms.Resize(256), transforms.CenterCrop(224), transforms.ToTensor(),transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])
image_datasets = datasets.ImageFolder(os.path.join(path_file,'test'), transforms_file)
workloader2 = torch.utils.data.DataLoader(image_datasets, batch_size=1, shuffle=True, num_workers=4)

# %%
# Предсказываем класс
classes_test = ['0', '1', '2', '3', '4', '5']
with torch.no_grad():
    for data in workloader2:
        images, labels = data
        images, labels = images.cuda(), labels.cuda()
        outputs = modelBR(images)
        _, predicted = torch.max(outputs.data, 1)
        for printdata in list(zip(predicted,labels,outputs)):
            printclass =[classes_test[int(printdata[0])],classes_test[int(printdata[1])]]
            print(u'Предсказанный класс по классификации BI-RADS - {0}'.format(printclass[0]))
# Out:
# Предсказанный класс по классификации BI-RADS - 4
